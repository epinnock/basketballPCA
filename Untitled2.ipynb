# %%
import requests
import pickle
import numpy as np
import matplotlib as mpl
mpl.use('Agg')
import matplotlib.pyplot as plt
from hmmlearn import hmm
from nbamovelib import *
from scipy.misc import imread

# %%
def getRawData(GameID,EventID):
     strs='http://stats.nba.com/stats/locations_getmoments?GameID=%s&EventID=%d'%(GameID,EventID)
     raw_data=requests.get(strs)
     print raw_data.status_code
     move=raw_data.json()['moments']
     visitor=raw_data.json()['visitor']['players']
     home=raw_data.json()['home']['players']
     numbers=[]
     for i in move[0][5]:
        numbers.append(i[1])
     print numbers   
     returner=[move,home,visitor,numbers]
     return returner

# %%
def getPlayerData(PlayerID,rawData):
    playerdata=[]
    for i in rawData:
        for j in i[5]:
            if j[1]==PlayerID:
                playerdata.append(j)
    playerdata=[[a[2],a[3]] for a in playerdata]
    return playerdata

# %%
myballdata= getBallData('0021400931',187)

# %%
def prepareBallData(ballData):
    x= np.array([a[0] for a in ballData])
    y= np.array([a[1] for a in ballData])
    x=x*10
    y=y*10
    return x,y
#print prepareBallData(myballdata)

# %%
def generatePlot(dataset):
   
   plt.scatter(dataset[0],dataset[1],alpha=.1,zorder=1)
   img=imread('fullcourt .png')
   plt.imshow(img,zorder=0)
   plt.show()

# %%
def assembleBallData(GameID,start,size):
    extendedballData=[]
    for i in range(start,(start+size)):
        try:
            a=getBallData('0021400931',i)
            if a is not None:
                extendedballData.extend(a)
        except:
            pass
    return extendedballData

generatePlot(prepareBallData(assembleBallData('0021400931',1,1)))

# %%
def assembleRawData(GameID,start,size):
    extendedRawData=[]
    for i in range(start,(start+size)):
        try:
            a=getRawData('0021400931',i)[0]
            if a is not None:
                extendedRawData.extend(a)
        except:
            pass
    return extendedRawData

# %%
player=(prepareBallData(getPlayerData(201168,assembleRawData('0021400931',3,1))))
ball=(prepareBallData(assembleBallData('0021400931',3,1)))
x=[]
y=[]

 
for i in range(len(player[0])):
    if distance([player[0][i],player[1][i]],[ball[0][i],ball[1][i]])<40:
        x.append(player[0][i])
        y.append(player[1][i])
possesion=[x,y]

plt.scatter(player[0],player[1],alpha=.1,zorder=1)
plt.scatter(ball[0],ball[1],alpha=.1,c='g',zorder=1)
plt.scatter(possesion[0],possesion[1],alpha=.2,c='r',zorder=1)
img=imread('fullcourt .png')
plt.imshow(img,zorder=0)
plt.suptitle('Poss:%f'%(float(len(possesion[0]))/float(len(player[0]))*100.0), fontsize=14, fontweight='bold')
plt.show()

# %%
import math
def distance(p1,p2):
    dist=math.sqrt(math.pow((p1[0]-p2[0]),2)+math.pow((p1[1]-p2[1]),2))
    #print dist
    return dist
print distance([3,3],[4,4])

# %%
#for team hometeam=1 visitors=2
def getTeamPossessionRate(rawData,team):
    balldata=[[a[0]*10.0,a[1]*10.0] for a in getPlayerData(-1,rawData[0])]
    myteam=[]
    total=0
    for p in rawData[team]:
        print (p['firstname'],p['playerid'])
      
        playerdata=[[a[0]*10.0,a[1]*10.0] for a in getPlayerData(p['playerid'],rawData[0])]
        
        pdata=playerPossession(playerdata,balldata,100.0)
        try:
            myteam.append(len(pdata[0]))
            total+=len(pdata[0])
           
        except:
            myteam.append(0)
           
        
    i=0
    print('total',total)
    for p in rawData[team]:
        p['poss']=(float(myteam[i])/float(total))*100.0
        i+=1
        if p['poss']>0.0:
            print p
    #print rawData[team]
    
getTeamPossessionRate(getRawData('0021400931',3),1)

# %%
def playerPossession(player,ball,mydistance):
    x=[]
    y=[]
    
    if(len(player)>0):
        for i in range(min(len(player),len(ball))):
            mydist= distance(player[i],ball[i])
            if(mydist<mydistance):
                x.append(player[i][0])
                y.append(player[i][1])
        possesion=[x,y]
        print len(x)
        return possesion
    else:
        return []

# %%
rawdata=getRawData('0021400931',3)
rawdata= rawdata[0]
for p in rawdata:
    p=p[5]
    cache=0
    min=1000.0
    ball=p[0]
    close=[]
    for i in range(1,10):
        point=p[i]
        dist=distance(point[2:4],ball[2:4])
        if dist<min:
            cache=i
            min=dist
    p[cache].append(min)
    close.append(p[cache])
    print close

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import LogisticRegression
def getShotDifficulty(mshotspossible,menc,mclf):
    last=0
    ret=[]
    for i in mshotspossible:
        if i[0] is not 0:
            stuff=menc.transform([i[0],i[2]]).toarray()[0].tolist()
            stuff.extend([i[1],i[3],i[4]])
            ans=mclf.predict_proba(stuff)
            last=(ans[0][0]*10)
            ret.append(last)
        else:
            ret.append(last)
    return ret

# %%
from matplotlib import animation
import time
import pickle
def animate(i,data,scat,mytimes,annotations,myhandler,defense,shotdist,diff,ballspeed,txt):
    scat.set_offsets(data[i])
    print len(annotations)
    for j in range(1,11):
        annotations[j-1].xytext = (data[i][j][0],data[i][j][1])
    try:
        txt.set_text("Shot Clock: %.1f \n ballhandler:%s \n Defense:%s Distance:%.1f \nShot Distance %.1f Difficulty: %.2f/10"%(mytimes[i],myhandler[i][0],defense[i][0],defense[i][1],shotdist[i],diff[i]))
        plt.draw()
    except:
        pass
    
    
        
    return scat,annotations
starttime=time.time()
playerdict=pickle.load(open('players.p'))
playerdict['In Air']=0
playerdict['None']=0
rawdata=getRawData('0021400186',205)
stuff=[]
times=[]
for i in rawdata[0]:
    times.append(i[3])
    stuff.append([[g[2]*10,g[3]*10]for g in i[5]])
names=[]
ballz=[i[5][0][4] for i in rawdata[0]]
enc=pickle.load(open('encoder.p','rb'))
clf=pickle.load(open('classifier.p','rb'))

for i in rawdata[1]:
    names.append([i['firstname']+' '+i['lastname'],i['playerid']])
for i in rawdata[2]:
    names.append([i['firstname']+' '+i['lastname'],i['playerid']])
found=[]
print names
for i in rawdata[3]:
   
    for j in names:
       
        if int(j[1]) == int(i):
            found.append(j[0])
            
            break
names=found
print names

ballhandler=[]
disthist=[]
defenders=[]
baskets=[[52,247],[884,247]]
basketdistance=[]
ball=[0,0]
ballspeed=[]
for moment in stuff:
    players=moment[1:]
    
    ballspeed.append(distance(moment[0],ball)*3.0)
    ball=moment[0]
    dist=[ distance(moment[0],i) for i in moment][1:]
    disthist.insert(0,dist)
    
    ballhandler.append([names[dist.index(min(dist))],min(dist)])
    handlerindex=dist.index(min(dist))
    
    handler=players[handlerindex]                
    players[handlerindex]=[10000,10000]
    basketdistance.append(min([distance(moment[0],i) for i in baskets])/10.0)
    defenderindex=0
    if(handlerindex>4):
        dist=[ distance(handler,i) for i in players[:5]]
        defenderindex=dist.index(min(dist))
    else:
        dist=[ distance(handler,i) for i in players[5:]]
        defenderindex=dist.index(min(dist))+5
    defenders.append([names[defenderindex],min(dist)/10.0])
if len(ballhandler)==len(stuff):
    print "Same Length"


shotspossible=[]    
for i in range(len(ballhandler)):
    if ballz[i]>8.0:
        ballhandler[i]=['In Air']
        defenders[i]=['None',0]
    shotspossible.append([playerdict[ballhandler[i][0]], times[i], playerdict[defenders[i][0]],defenders[i][1],basketdistance[i]])
shotdiff=getShotDifficulty(shotspossible,enc,clf)
print shotdiff
fig = plt.figure()
ax1 = plt.axes(frameon=False)
plt.axis('off')
fig.text(0.58, 0.25, '@epinnock',
         fontsize= 16, color='red',
         ha='right', va='bottom', alpha=0.5)
#diff=np.hstack(player)
txt = fig.suptitle("Shot Clock: ")
scat=plt.scatter([],[],c=['g','b','b','b','b','b','r','r','r','r','r'],alpha=1,zorder=1)


img=imread('fullcourt .png')
plt.imshow(img,zorder=0)
annotations=[]
for i in names:
    ann=plt.annotate(i.split()[1],[0,0],fontsize=6)
    ann.set_animated(True)
    annotations.append(ann)
anim = animation.FuncAnimation(fig, animate, frames=len(stuff),fargs=(stuff, scat,times,annotations,ballhandler,defenders,basketdistance,shotdiff,ballspeed,txt),interval=20)
anim.save('basic_animation.mp4', fps=25, extra_args=['-vcodec', 'libx264'])

print (time.time()-starttime, 'secs')
# Out:
# 200
# [-1, 1890, 2034, 203925, 202681, 202684, 101236, 200768, 101150, 202349, 202335]
# [[u'Shawn Marion', 1890], [u'Mike Miller', 2034], [u'Brendan Haywood', 2217], [u'LeBron James', 2544], [u'James Jones', 2592], [u'Anderson Varejao', 2760], [u'Lou Amundson', 200811], [u'Kevin Love', 201567], [u'Kyrie Irving', 202681], [u'Tristan Thompson', 202684], [u'Dion Waiters', 203079], [u'Will Cherry', 203805], [u'Joe Harris', 203925], [u'Lou Williams', 101150], [u'Amir Johnson', 101161], [u'Charles Hayes', 101236], [u'Kyle Lowry', 200768], [u'Greg Stiemsma', 201880], [u'DeMar DeRozan', 201942], [u'Patrick Patterson', 202335], [u'Greivis Vasquez', 202349], [u'Landry Fields', 202361], [u'Jonas Valanciunas', 202685], [u'Terrence Ross', 203082], [u'Lucas Nogueira', 203512], [u'Bruno Caboclo', 203998]]
# ...

# %%
rawdata=getRawData('0021400931',153)
stuff=[]
for i in rawdata[0]:
    print i
    stuff.append([[g[2]*10,g[3]*10]for g in i[5]])
print stuff[0]

# %%
searchbox=[[2,'two'],[1,'onde']]
search=[1,2]
found=[]
for i in search:
    for j in searchbox:
        if j[0] is i:
            found.append(j[1])
            break
print found

# %%
import json
teams=[1610612755,1610612766,1610612749,1610612741,1610612739,1610612738,1610612737,1610612748,1610612752,1610612753,1610612751,1610612754,1610612765,1610612761,1610612764,1610612746,1610612763,1610612740,1610612762,1610612758,1610612747,1610612742,1610612743,1610612745,1610612759,1610612756,1610612760,1610612750,1610612757,1610612744]
print len(teams)
for team in teams:
    link="http://stats.nba.com/stats/teamplayerdashboard?DateFrom=&DateTo=&GameSegment=&LastNGames=0&LeagueID=00&Location=&MeasureType=Base&Month=0&OpponentTeamID=0&Outcome=&PaceAdjust=N&PerMode=PerGame&Period=0&PlusMinus=N&Rank=N&Season=2014-15&SeasonSegment=&SeasonType=Regular+Season&TeamID=%d&VsConference=&VsDivision="
    mylink=link%(team)
    print mylink
    teamplayers=requests.get(mylink).json()['resultSets'][1]['rowSet']
    playerids=[]
    for player in teamplayers:
        playerids.append(player[1])
    print playerids

    
    shotchartlink="http://stats.nba.com/stats/shotchartdetail?Season=2014-15&SeasonType=Regular+Season&TeamID=0&PlayerID=%d&GameID=&Outcome=&Location=&Month=0&SeasonSegment=&DateFrom=&DateTo=&OpponentTeamID=0&VsConference=&VsDivision=&Position=&RookieYear=&GameSegment=&Period=0&LastNGames=0&ContextFilter=&ContextMeasure=FGA"
    for i in playerids:
        mylink=shotchartlink%(i)
        with open("shotcharts/%d"%(i),'w') as outfile:
            json.dump(requests.get(mylink).json(), outfile)
            print (i,'done')
    
    print (team,'done')

# %%
teams=[1610612755,1610612766,1610612749,1610612741,1610612739,1610612738,1610612737,1610612748,1610612752,1610612753,1610612751,1610612754,1610612765,1610612761,1610612764,1610612746,1610612763,1610612740,1610612762,1610612758,1610612747,1610612742,1610612743,1610612745,1610612759,1610612756,1610612760,1610612750,1610612757,1610612744]
print len(teams)
exceptions=[]
for team in teams:
    link="http://stats.nba.com/stats/teamplayerdashboard?DateFrom=&DateTo=&GameSegment=&LastNGames=0&LeagueID=00&Location=&MeasureType=Base&Month=0&OpponentTeamID=0&Outcome=&PaceAdjust=N&PerMode=PerGame&Period=0&PlusMinus=N&Rank=N&Season=2014-15&SeasonSegment=&SeasonType=Regular+Season&TeamID=%d&VsConference=&VsDivision="
    mylink=link%(team)
    print mylink
    teamplayers=requests.get(mylink).json()['resultSets'][1]['rowSet']
    playerids=[]
    for player in teamplayers:
        playerids.append(player[1])
    print playerids

    
    shotloglink="http://stats.nba.com/stats/playerdashptshotlog?DateFrom=&DateTo=&GameSegment=&LastNGames=0&LeagueID=00&Location=&Month=0&OpponentTeamID=0&Outcome=&Period=0&PlayerID=%d&Season=2014-15&SeasonSegment=&SeasonType=Regular+Season&TeamID=0&VsConference=&VsDivision="
    for i in playerids:
        mylink=shotloglink%(i)
        try:
            with open("shotlogs/%d"%(i),'w') as outfile:
                json.dump(requests.get(mylink).json(), outfile)
                print (i,'done')
        except:
            exceptions.append(mylink)
            print('exceptions',mylink) 
    
    print (team,'done')

# %%
result=requests.get('http://stats.nba.com/stats/shotchartdetail?Season=2014-15&SeasonType=Regular%20Season&TeamID=0&PlayerID=203457&GameID=&Outcome=&Location=&Month=0&SeasonSegment=&DateFrom=&DateTo=&OpponentTeamID=0&VsConference=&VsDivision=&Position=&RookieYear=&GameSegment=&Period=0&LastNGames=0&ContextFilter=&ContextMeasure=FGA').json()
result= result['resultSets'][1]['rowSet']
sum=0
for i in result:
    sum+=i[4]
print sum

# %%
import pickle
import time
response= requests.get('http://stats.nba.com/stats/playerdashptshotlog?DateFrom=&DateTo=&GameSegment=&LastNGames=0&LeagueID=00&Location=&Month=0&OpponentTeamID=0&Outcome=&Period=0&PlayerID=2225&Season=2014-15&SeasonSegment=&SeasonType=Regular+Season&TeamID=0&VsConference=&VsDivision=').json()
shots= response['resultSets'][0]['rowSet']
made=0.0
hothand=0.0
lastmade=False
shotlogs=[]
for shot in shots:
    shotclock=shot[8]
    if shotclock is None:
        shotclock=time.strptime(shot[7],'%M:%S')[5]
   
    shotlogs.append([2225,shotclock,shot[15],shot[16],shot[11],shot[13]])
    if lastmade and (str(shot[13])== 'made'):
        hothand+=1
    if shot[13]=='made':
        lastmade=True
        made+=1
    else:
        lastmade=False
print (hothand/made,(made-hothand)/(len(shots)-made))
pickle.dump( shotlogs, open( "shotlog.p", "wb" ) )

# %%
shots=pickle.load(open('shotlog.p','rb'))
print shots

# %%
import time

print time.strptime("0:17",'%M:%S')[5]

# %%
rawdata=getRawData('0021500048',134)
stuff=[]
times=[]


for i in rawdata[0]:
    times.append(i[3])
    stuff.append([[g[2]*10,g[3]*10]for g in i[5]])
found=[]
names=[]

for i in rawdata[1]:
    names.append([i['lastname'],i['playerid']])
for i in rawdata[2]:
    names.append([i['lastname'],i['playerid']])
print names
for i in rawdata[3]:
   
    for j in names:
       
        if int(j[1]) == int(i):
            found.append(j[0])
            break
names=found
print 'stuff'  
print len(rawdata[3])
ballhandler=[]
for moment in stuff:
    dist=[ distance(moment[0],i) for i in moment][1:]
    ballhandler.append(names[dist.index(min(dist))],min(dist))

# %%
from hmmlearn.hmm import GaussianHMM
playerdict=pickle.load(open('players.p'))
playerdict['In Air']=0
playerdict['None']=0
rawdata=getRawData('0021400186',204)
stuff=[]
times=[]
for i in rawdata[0]:
    times.append(i[3])
    stuff.append([[g[2]*10,g[3]*10]for g in i[5]])
names=[]
ballz=[i[5][0][4] for i in rawdata[0]]
ballzspeed=[ballz[i+1]-ballz[i] for i in range(len(ballz)-1)]
enc=pickle.load(open('encoder.p','rb'))
clf=pickle.load(open('classifier.p','rb'))

for i in rawdata[1]:
    names.append([i['firstname']+' '+i['lastname'],i['playerid']])
for i in rawdata[2]:
    names.append([i['firstname']+' '+i['lastname'],i['playerid']])
found=[]
print names
for i in rawdata[3]:
   
    for j in names:
       
        if int(j[1]) == int(i):
            found.append(j[0])
            
            break
names=found
print names

ballhandler=[]
defenders=[]
baskets=[[52,247],[884,247]]
basketdistance=[]
ball=[0,0]
ballspeed=[]
for moment in stuff:
    players=moment[1:]
    
    ballspeed.append(distance(moment[0],ball)*3.0)
    ball=moment[0]
    dist=[ distance(moment[0],i) for i in moment][1:]
    ballhandler.append([names[dist.index(min(dist))],min(dist)])
    handlerindex=dist.index(min(dist))
    
    handler=players[handlerindex]                
    players[handlerindex]=[10000,10000]
    basketdistance.append(min([distance(moment[0],i) for i in baskets])/10.0)
    defenderindex=0
    if(handlerindex>4):
        dist=[ distance(handler,i) for i in players[:5]]
        defenderindex=dist.index(min(dist))
    else:
        dist=[ distance(handler,i) for i in players[5:]]
        defenderindex=dist.index(min(dist))+5
    defenders.append([names[defenderindex],min(dist)/10.0])
if len(ballhandler)==len(stuff):
    print "Same Length"
ballz=np.asarray(ballz)
ballspeed[0]=0
ballspeed=np.asarray(ballspeed)
print ballspeed
print ballz
X = np.column_stack([ballz,ballspeed])
print ('shape',X.shape)
print X.ndim
print X[0]
n_components=3
model = hmm.GaussianHMM(n_components, covariance_type="diag", n_iter=1000)

model.fit(X)
# predict the optimal sequence of internal hidden state
hidden_states = model.predict(X)

frames=np.arange(len(hidden_states))
plt.plot(ballz)
ballspeed[0]=0.0
plt.plot(ballspeed)
colors=['red','green','blue']
ballstateav=[]
statestring=["shoot","pass","possess"]
for i in xrange(n_components):
    state=i
    # use fancy indexing to plot data in each state
    idx = (hidden_states == i)
    idy=[50 for i in frames[idx]]
    ballstateav.append(np.mean(ballz[idx]))
    print('ballz average for state %d %f'%(state,np.mean(ballz[idx])))
    print len(idy)
    print len(frames[idx])
    plt.plot( frames[idx],idy, 'o', color=colors[state] ,label="%dth hidden state" % i)

ballstateav=[ballstateav.index(i) for i in sorted(ballstateav, reverse=True)]
mystatestring=[statestring[ballstateav.index(i)]  for i in range(len(ballstateav))]

print ballstateav
print mystatestring
givenstate=[mystatestring[i] for i in hidden_states]

plt.ylabel('some numbers')
plt.show()
# Out:
# 200
# [-1, 1890, 2034, 203925, 202681, 202684, 101236, 200768, 101150, 202349, 202335]
# [[u'Shawn Marion', 1890], [u'Mike Miller', 2034], [u'Brendan Haywood', 2217], [u'LeBron James', 2544], [u'James Jones', 2592], [u'Anderson Varejao', 2760], [u'Lou Amundson', 200811], [u'Kevin Love', 201567], [u'Kyrie Irving', 202681], [u'Tristan Thompson', 202684], [u'Dion Waiters', 203079], [u'Will Cherry', 203805], [u'Joe Harris', 203925], [u'Lou Williams', 101150], [u'Amir Johnson', 101161], [u'Charles Hayes', 101236], [u'Kyle Lowry', 200768], [u'Greg Stiemsma', 201880], [u'DeMar DeRozan', 201942], [u'Patrick Patterson', 202335], [u'Greivis Vasquez', 202349], [u'Landry Fields', 202361], [u'Jonas Valanciunas', 202685], [u'Terrence Ross', 203082], [u'Lucas Nogueira', 203512], [u'Bruno Caboclo', 203998]]
# [u'Shawn Marion', u'Mike Miller', u'Joe Harris', u'Kyrie Irving', u'Tristan Thompson', u'Charles Hayes', u'Kyle Lowry', u'Lou Williams', u'Greivis Vasquez', u'Patrick Patterson']
# Same Length
# ...

# %%
import nbamovelib

nbamovelib.testLib()
# Out:
# hello test lib

# %%
import random
def trys():
   
    if(random.random()>.8):
        return True
    return False

while(not trys()):
    print "i tried"
print 'done'

# %%
currentstate='none'
currentballhandler='none'
statelife=0
print(len(givenstate)," ",len(ballhandler))
for i in range(len(givenstate)):
    if ((ballhandler[i][0] is not currentballhandler)):
        print statelife
        print (ballhandler[i][0]," ",givenstate[i]," ",i)
        currentstate=givenstate[i]
        currentballhandler=ballhandler[i][0]
        statelife=0
    else:
        statelife+=1
print
# Out:
# (1025, ' ', 1025)
# 0
# (u'Tristan Thompson', ' ', 'possess', ' ', 0)
# 8
# (u'Kyrie Irving', ' ', 'possess', ' ', 9)
# 198
# (u'Greivis Vasquez', ' ', 'pass', ' ', 208)
# 1
# (u'Tristan Thompson', ' ', 'pass', ' ', 210)
# 6
# (u'Joe Harris', ' ', 'pass', ' ', 217)
# 52
# (u'Kyrie Irving', ' ', 'possess', ' ', 270)
# 17
# (u'Greivis Vasquez', ' ', 'possess', ' ', 288)
# 32
# (u'Kyrie Irving', ' ', 'possess', ' ', 321)
# 57
# ('In Air', ' ', 'shoot', ' ', 379)
# 66
# (u'Charles Hayes', ' ', 'shoot', ' ', 446)
# 2
# (u'Patrick Patterson', ' ', 'shoot', ' ', 449)
# 5
# (u'Charles Hayes', ' ', 'possess', ' ', 455)
# 16
# (u'Lou Williams', ' ', 'pass', ' ', 472)
# 122
# ('In Air', ' ', 'shoot', ' ', 595)
# 41
# (u'Shawn Marion', ' ', 'shoot', ' ', 637)
# 11
# (u'Tristan Thompson', ' ', 'possess', ' ', 649)
# 7
# (u'Kyrie Irving', ' ', 'possess', ' ', 657)
# 87
# (u'Tristan Thompson', ' ', 'pass', ' ', 745)
# 0
# ('In Air', ' ', 'pass', ' ', 746)
# 2
# ...

# %%
q=[]
for i in range(4):
    q.insert(0,i)

print q.pop()
# Out:
# 0
